# %% [markdown]
# <a href="https://colab.research.google.com/github/yurimmmmmm/Python_Data_Analysis_and_Image_Processing/blob/main/OpenCV_%EC%9D%B4%EB%AF%B8%EC%A7%80_%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ccd6d62-2758-48f8-9292-81f28cafde1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ccd6d62-2758-48f8-9292-81f28cafde1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ab3979c-2b04-4900-8344-b4e91de024d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ab3979c-2b04-4900-8344-b4e91de024d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt

image1 = cv2.imread('img_A.jpeg')
image2 = cv2.imread('20220906_140851.png')
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
print(image2.shape)

(h, w) = image1.shape[:2]
image2 = cv2.resize(image2, (w, h))
#assert image1.shape == image2.shape
result = cv2.add(image1, image2)
result1 = image1 + image2

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()

plt.imshow(cv2.cvtColor(result1, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (1080, 1920, 3)

# %%
import matplotlib.pyplot as plt

image1 = cv2.imread('img_A.jpeg')
image2 = cv2.imread('20220906_140851.png')
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
print(image2.shape)

(h, w) = image1.shape[:2]
image2 = cv2.resize(image2, (w, h))
result = cv2.add(image1, image2)
result1 = image1 + image2

plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()

plt.imshow(cv2.cvtColor(result1, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (1080, 1920, 3)
