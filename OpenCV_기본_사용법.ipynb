# %% [markdown]
# <a href="https://colab.research.google.com/github/yurimmmmmm/Python_Data_Analysis_and_Image_Processing/blob/main/OpenCV_%EA%B8%B0%EB%B3%B8_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd75383f-491c-4d56-8412-30f516a09e6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd75383f-491c-4d56-8412-30f516a09e6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cv2.imread(file_name,flag): 이미지를 읽어 Numpy 객체로 만드는 함수
file_name: 읽고자 하는 이미지 파일
flag: 이미지를 읽는 방법 설정
IMREAD_COLOR: 이미지를 COLOR로 읽고 투명한 부분 무시
IMREAD_GRAY: 이미지를 Grayscale로 읽기
IMREAD_INCHANGED: 이미지를 Color로 읽고 투명한 부분도 읽기

반환 값: Numpy객체 (행,열, 색상: 기본 BGR)

cv2.imshow(title, image)
title: 윈도우 창의 제목
image: 출력할 이미지 객체

cv2.imwrite(file_name, image): 특정한 이미지를 파일로 저장
file_name: 저장할 이미지 파일 이름
image: 저장할 이미지 객체

cv2,wait(time): 키보드 입력을 처리하는 함수
time: 입력 대기 시간(무한대기: 0)

cv2.destoryAllWindows(): 화면의 모든 윈도우를 닫는 함수

# %%
import matplotlib.pyplot as plt

img_basic = cv2.imread('img_A.jpeg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic = cv2.imread('img_A.jpeg', cv2.IMREAD_UNCHANGED)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic = cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
